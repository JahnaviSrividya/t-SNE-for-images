# %%
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patheffects as pe
# %matplotlib inline

import sklearn
from sklearn.manifold import TSNE 
from sklearn.datasets import load_digits # For the UCI ML handwritten digits dataset

import seaborn as sb

digits = load_digits()
print(digits.data.shape) # There are 10 classes (0 to 9) with alomst 180 images in each class 
                         # The images are 8x8 and hence 64 pixels(dimensions)
plt.gray();
#Displaying what the standard images look like
for i in range(0,10):
    plt.matshow(digits.images[i]) 
    plt.show()
# Out:
# (1797, 64)

# %%
X = np.vstack([digits.data[digits.target==i] for i in range(10)]) # Place the arrays of data of each digit on top of each other and store in X
Y = np.hstack([digits.target[digits.target==i] for i in range(10)]) # Place the arrays of data of each target digit by the side of each other continuosly and store in Y

# %%
#Implementing the TSNE Function


#1. perplexity=20 random_state=1
digits_final = TSNE(perplexity=20,random_state=1).fit_transform(X) 

#So, here is a utility function that helps to do a scatter plot of the transformed data 

def plot(x, colors):
  
    palette = np.array(sb.color_palette("hls", 10))  #Choosing color palette 

    # Create a scatter plot.
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40, c=palette[colors.astype(np.int)])
    # Add the labels for each digit.
    txts = []
    for i in range(10):
        # Position of each label.
        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([pe.Stroke(linewidth=5, foreground="w"), pe.Normal()])
        txts.append(txt)
    return f, ax, txts


plot(digits_final,Y)
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fe2d90e9a58>,
#  [Text(-74.99273, -1.3069372, '0'),
#   Text(2.1608348, -29.506931, '1'),
#   Text(37.930363, -47.442154, '2'),
#   Text(-1.1950201, 24.868298, '3'),
#   Text(-36.588657, -49.235203, '4'),
#   Text(-0.4554127, 62.325256, '5'),
#   Text(60.850132, 3.1264818, '6'),
#   Text(-35.98746, 10.476263, '7'),
#   Text(12.985327, -9.185638, '8'),
#   Text(26.224922, 37.14853, '9')])

# %%
#2. perplexity=5
digits_final = TSNE(perplexity=5).fit_transform(X) 


#So, here is a utility function that helps to do a scatter plot of the transformed data 

def plot(x, colors):
  
    palette = np.array(sb.color_palette("hls", 10))  #Choosing color palette 

    # Create a scatter plot.
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40, c=palette[colors.astype(np.int)])
    # Add the labels for each digit.
    txts = []
    for i in range(10):
        # Position of each label.
        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([pe.Stroke(linewidth=5, foreground="w"), pe.Normal()])
        txts.append(txt)
    return f, ax, txts


plot(digits_final,Y)
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fe2d55da128>,
#  [Text(-34.311684, -64.93366, '0'),
#   Text(46.774628, -12.80529, '1'),
#   Text(-48.253326, 51.309826, '2'),
#   Text(-36.179195, 3.0477746, '3'),
#   Text(5.236945, 71.04839, '4'),
#   Text(32.26422, -65.65528, '5'),
#   Text(2.8440611, -29.780138, '6'),
#   Text(66.094124, 34.40044, '7'),
#   Text(10.757613, 14.040684, '8'),
#   Text(-73.13364, -9.30842, '9')])

# %%
#3. perplexity=50
digits_final = TSNE(perplexity=50).fit_transform(X) 

#So, here is a utility function that helps to do a scatter plot of the transformed data 

def plot(x, colors):
  
    palette = np.array(sb.color_palette("hls", 10))  #Choosing color palette 

    # Create a scatter plot.
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40, c=palette[colors.astype(np.int)])
    # Add the labels for each digit.
    txts = []
    for i in range(10):
        # Position of each label.
        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([pe.Stroke(linewidth=5, foreground="w"), pe.Normal()])
        txts.append(txt)
    return f, ax, txts


plot(digits_final,Y)
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fe2c84f7e48>,
#  [Text(-11.280796, -47.140495, '0'),
#   Text(2.0510745, 14.483431, '1'),
#   Text(36.71595, 16.085587, '2'),
#   Text(28.152342, -12.11745, '3'),
#   Text(-28.825577, 23.394114, '4'),
#   Text(-6.248023, -13.63307, '5'),
#   Text(-39.596134, -8.602498, '6'),
#   Text(1.5869458, 38.95345, '7'),
#   Text(11.480612, 3.9000525, '8'),
#   Text(11.946594, -20.019405, '9')])

# %%
#4. perplexity=10 steps=9000
digits_final = TSNE(perplexity=10,n_iter=9000).fit_transform(X) 


#So, here is a utility function that helps to do a scatter plot of the transformed data 

def plot(x, colors):
  
    palette = np.array(sb.color_palette("hls", 10))  #Choosing color palette 

    # Create a scatter plot.
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40, c=palette[colors.astype(np.int)])
    # Add the labels for each digit.
    txts = []
    for i in range(10):
        # Position of each label.
        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([pe.Stroke(linewidth=5, foreground="w"), pe.Normal()])
        txts.append(txt)
    return f, ax, txts


plot(digits_final,Y)
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fe2d909b8d0>,
#  [Text(128.6598, 5.6682673, '0'),
#   Text(-24.941723, -16.310478, '1'),
#   Text(-57.5356, 38.128162, '2'),
#   Text(0.22307752, 57.366478, '3'),
#   Text(-20.042465, -81.114136, '4'),
#   Text(48.652138, 8.16187, '5'),
#   Text(-109.3422, -18.33148, '6'),
#   Text(36.88312, -59.486816, '7'),
#   Text(-9.002857, 10.091507, '8'),
#   Text(27.83596, 43.55559, '9')])

# %%
#5. perplexity=25
digits_final = TSNE(perplexity=25).fit_transform(X) 

#So, here is a utility function that helps to do a scatter plot of the transformed data 

def plot(x, colors):
  
    palette = np.array(sb.color_palette("hls", 10))  #Choosing color palette 

    # Create a scatter plot.
    f = plt.figure(figsize=(8, 8))
    ax = plt.subplot(aspect='equal')
    sc = ax.scatter(x[:,0], x[:,1], lw=0, s=40, c=palette[colors.astype(np.int)])
    # Add the labels for each digit.
    txts = []
    for i in range(10):
        # Position of each label.
        xtext, ytext = np.median(x[colors == i, :], axis=0)
        txt = ax.text(xtext, ytext, str(i), fontsize=24)
        txt.set_path_effects([pe.Stroke(linewidth=5, foreground="w"), pe.Normal()])
        txts.append(txt)
    return f, ax, txts


plot(digits_final,Y)
# Out:
# (<Figure size 576x576 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7fe2c84830f0>,
#  [Text(-65.78806, 5.419778, '0'),
#   Text(18.217487, -22.012936, '1'),
#   Text(56.44238, -7.0568657, '2'),
#   Text(36.004135, 31.625141, '3'),
#   Text(-2.257948, -58.738594, '4'),
#   Text(-17.33508, 40.96721, '5'),
#   Text(-41.618034, -34.69601, '6'),
#   Text(-18.668964, -0.11960749, '7'),
#   Text(16.153908, 3.075553, '8'),
#   Text(10.799075, 46.297718, '9')])
